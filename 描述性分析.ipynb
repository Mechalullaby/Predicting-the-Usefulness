# %%
import pandas as pd

# %%
df = pd.read_excel('耳机.xlsx')

# %%
df.describe()
# Out:
#              Words         Nsub         Asub          Adj          Adv  \
# count  1032.000000  1032.000000  1032.000000  1032.000000  1032.000000
# mean     26.843992     4.105620     6.314236     1.576550     2.085271
# std      32.270887     4.166455     2.749358     1.561526     2.535585
# min       1.000000     1.000000     1.000000     0.000000     0.000000
# 25%      10.000000     2.000000     4.333333     0.000000     0.000000
# 50%      17.000000     3.000000     6.000000     1.000000     1.000000
# 75%      30.000000     5.000000     8.000000     2.000000     3.000000
# max     348.000000    45.000000    29.000000    11.000000    19.000000
#
#                Ver      Entropy    Diversity     Polarity    Relevancy  \
# count  1032.000000  1032.000000  1032.000000  1032.000000  1032.000000
# mean      3.437016     1.609645     0.939000     0.318803     5.916667
# std       5.124058     1.707874     0.093279     0.322116     6.362996
# ...
